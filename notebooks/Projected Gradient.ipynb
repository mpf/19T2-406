# %%
using Optim, ForwardDiff, LinearAlgebra

# %% [markdown]
# The n-variable Rosenbrock test function is
#
# $$
# f(x) = \sum_{i=1}^{N-1}[100(x_{i+1} - x_{i}^2)^2+(1-x_i)^2].
# $$
#
# Define the 3-variable Rosenbrock test function.

# %%
N = 3;
f3(x)= 100.0 * (x[2] - x[1]^2)^2 + (1-x[1])^2 + 100.0 * (x[3]-x[2]^2)^2+(1-x[2])^2
# Out:
# f3 (generic function with 1 method)

# %%
g(x) = ForwardDiff.gradient(f3, x)
# Out:
# g (generic function with 1 method)

# %% [markdown]
# The linear constraint is $x_1+x_2+x3 = 1$ and $2x_1+x_2 = 0.5$.

# %%
a1 = ones(1,3) ; b1 = 1
a2 = [2 1 0]; b2 = 0.5
A = vcat(a1,a2); b = vcat(b1,b2);

# %% [markdown]
# let $C = \{x | Ax = b\}$. Projection on to C is $\text{proj}_{\mathcal C} (z) = z - A^\intercal(AA^\intercal)^{-1}(b-Az)$

# %%
proj(z) = z - A'* ( (A*A') \ (-A*z+b))
# Out:
# proj (generic function with 1 method)

# %%
proj(randn(3))
# Out:
# 3-element Array{Float64,1}:
#  0.22915585774642863
#  0.04168828450714268
#  0.7291558577464284

# %%
xk = zeros(3);
step = .0001;
for i in 1:500
    xk = xk - step * g(xk);
    xk = proj(xk)
    println(norm(xk))
end
# Out:
# 0.6767571942728058
# 1.9902180909899618
# 4.4415510472267785
# 8.569924027093885
# 14.671245551868004
# 25.700131365577217
# 45.413738924938855
# 77.25545093552722
# 159.30219874657897
# 51923.307283420705
# 8.967928429307152e12
# 5.025225240870303e37
# 8.927982480968099e111
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN

# %%
xk
# Out:
# 3-element Array{Float64,1}:
#  0.026982494544471283
#  0.4460350109110574
#  0.5269824945444714
